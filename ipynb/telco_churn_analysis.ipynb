# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Overall churn rate (percentage of attrition)
churn_rate = df['Churn'].value_counts(normalize=True) * 100
print("Overall churn rate:", round(churn_rate['Yes'], 2), "%")
# Out:
# Overall churn rate: 26.58 %

# %%
# Distribution schedule  churn
plt.figure(figsize=(8,5))
sns.countplot(x='Churn', data=df, palette='viridis')
plt.title('Churn Distribution (Yes/No)')
plt.show()
# Out:
# /tmp/ipython-input-1708668208.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette='viridis')

# %%
# 2. Churn by contract type
plt.figure(figsize=(10,6))
sns.countplot(x='Contract', hue='Churn', data=df, palette='viridis')
plt.title('Churn by contract type')
plt.show()

# %%
# 3. Churn by type of internet service
plt.figure(figsize=(10,6))
sns.countplot(x='InternetService', hue='Churn', data=df, palette='viridis')
plt.title('Churn by type of internet service')
plt.show()

# %%
# 4. Churn dependence on monthly payment
plt.figure(figsize=(10,6))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df, palette='viridis')
plt.title('Monthly Charges vs Churn')
plt.show()
# Out:
# /tmp/ipython-input-1032022721.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Churn', y='MonthlyCharges', data=df, palette='viridis')
